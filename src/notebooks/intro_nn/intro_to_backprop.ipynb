# %% [markdown]
# Consider the following neural net architecture and setup equations for outputs and derivatives for backpropogation
#
# ![image.png](attachment:image.png)
#
# ```
# Given the following formulas for h1 and h2:
#
# z1 = (w1.x1+w2.x2+b1)
# z2= (w3.x1+w4.x2+b1)
#
# as well as the following cost function
# J = (o1-y1)^2 + (o2-y2)^2
# ```
#
# ## Solve
# - setup equations for o1 and o2 in terms of z1 and z2
# - calculate derivatives on J over w5, w1 and b2

# %% [markdown]
# ```
# z1 = (w1.x1 + w2.x2 + b1)
# z2 = (w3.x1 + w4.x2 + b1)
#
# a1 = z1
# a2 = z2
#
# o1 = (w5.a1 + w7.a2 + b2)
# o2 = (w6.a1 + w8.a2 + b2)
#
# J = (o1-y1)^2 + (o2-y2)^2
#
# dJ_over_w5 = dJ_over_o1 . do1_over_w5
# dJ_over_w1 = dJ_over_o1 . do1_over_a1 . da1_over_z1 . dz1_over_w1
# dJ_over_b2 = (dJ_over_o1 . do1_over_b2) +  (dJ_over_o2 . do2_over_b2)
#
# dJ_over_o1 = 2.(o1 - y1).1
# do1_over_w5 = a1
#
# ```
